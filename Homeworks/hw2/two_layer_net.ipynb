# %% [markdown]
# # Полносвязные нейронные сети
#
# В этом упражнении мы реализуем полносвязные сети, используя модульный подход. Для каждого слоя мы реализуем функции `forward` и `backward`. Функция `forward` получает входы, веса и другие параметры и возвращает выход, а также объект `cache`, в котором сохраняются данные, необходимые для обратного прохода, например:
#
# ```python
# def layer_forward(x, w):
#   """Получает входы x и веса w"""
#   # Выполняем вычисления ...
#   z = # ... промежуточные результаты
#   # ...
#   out = # ... итоговый выход
#   cache = (x, w, z, out) # сохраняем всё нужное для backward
#   return out, cache
# ```
#
# Функция `backward` получает производные по выходу и объект `cache`, после чего вычисляет производные по входам и весам:
#
# ```python
# def layer_backward(dout, cache):
#   """Получает производные по выходу и кэш"""
#   # Распаковываем значения из cache
#   x, w, z, out = cache
#   # Выполняем вычисления ...
#   dx = # градиент по x
#   dw = # градиент по w
#   return dx, dw
# ```
#
# После реализации всех слоёв мы соберём их в двухслойную сеть с архитектурой `affine - relu - affine - softmax`.
#
# # Введение
# Ниже предстоит реализовать линейный слой и слой RELU. Как было рассмотрено ранее, на линейном слое выполняется линейное преобразование, а на слое RELU - добавляется нелинейность. Поскольку у нас стоит задача классификации (многоклассовой), то ответы мы будем получать через Softmax
#
#
# Перед выполнением задания нужно скачать датасет - в папке datasets есть файл с указанием путей для скачивания

# %%
# Базовая настройка окружения
from __future__ import print_function
import time
import numpy as np
import matplotlib.pyplot as plt
from classifiers.fc_net import *
from utils.data_utils import get_CIFAR10_data
from utils.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from utils.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0)  # размер графиков по умолчанию
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Автоперезагрузка внешних модулей
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Возвращает максимальную относительную ошибку."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Загружаем предварительно обработанный CIFAR-10
data = get_CIFAR10_data()
for k, v in list(data.items()):
  print(('%s: ' % k, v.shape))
# Out:
# ('X_train: ', (49000, 3, 32, 32))
# ('y_train: ', (49000,))
# ('X_val: ', (1000, 3, 32, 32))
# ('y_val: ', (1000,))
# ('X_test: ', (1000, 3, 32, 32))
# ('y_test: ', (1000,))

# %% [markdown]
# # Полносвязный слой: прямой проход
#
# Откройте файл `utils/layers.py` и реализуйте функцию `affine_forward`.
#
# После этого можно проверить реализацию, запустив следующую ячейку:

# %%
# Test the affine_forward function

num_inputs = 2
input_shape = (4, 5, 6)
output_dim = 3

input_size = num_inputs * np.prod(input_shape)
weight_size = output_dim * np.prod(input_shape)

x = np.linspace(-0.1, 0.5, num=input_size).reshape(num_inputs, *input_shape)
w = np.linspace(-0.2, 0.3, num=weight_size).reshape(np.prod(input_shape), output_dim)
b = np.linspace(-0.3, 0.1, num=output_dim)

out, _ = affine_forward(x, w, b)
correct_out = np.array([[ 1.49834967,  1.70660132,  1.91485297],
                        [ 3.25553199,  3.5141327,   3.77273342]])

# Compare your output with ours. The error should be around e-9 or less.
print('Testing affine_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing affine_forward function:
# difference:  9.769849468192957e-10

# %% [markdown]
# # Полносвязный слой: обратный проход
#
# Теперь реализуйте функцию `affine_backward` и проверьте её с помощью численной проверки градиента.

# %%
# Test the affine_backward function
np.random.seed(231)
x = np.random.randn(10, 2, 3)
w = np.random.randn(6, 5)
b = np.random.randn(5)
dout = np.random.randn(10, 5)

dx_num = eval_numerical_gradient_array(lambda x: affine_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_forward(x, w, b)[0], b, dout)

_, cache = affine_forward(x, w, b)
dx, dw, db = affine_backward(dout, cache)

# The error should be around e-10 or less
print('Testing affine_backward function:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_backward function:
# dx error:  5.399100368651805e-11
# dw error:  9.904211865398145e-11
# db error:  2.4122867568119087e-11

# %% [markdown]
# # Активация ReLU: прямой проход
#
# Реализуйте прямой проход для функции активации ReLU в `relu_forward`, а затем проверьте реализацию следующей ячейкой:

# %%
# Test the relu_forward function

x = np.linspace(-0.5, 0.5, num=12).reshape(3, 4)

out, _ = relu_forward(x)
correct_out = np.array([[ 0.,          0.,          0.,          0.,        ],
                        [ 0.,          0.,          0.04545455,  0.13636364,],
                        [ 0.22727273,  0.31818182,  0.40909091,  0.5,       ]])

# Compare your output with ours. The error should be on the order of e-8
print('Testing relu_forward function:')
print('difference: ', rel_error(out, correct_out))
# Out:
# Testing relu_forward function:
# difference:  4.999999798022158e-08

# %% [markdown]
# # Активация ReLU: обратный проход
#
# Теперь реализуйте обратный проход для ReLU в `relu_backward` и проверьте его с помощью численной проверки градиента:

# %%
np.random.seed(231)
x = np.random.randn(10, 10)
dout = np.random.randn(*x.shape)

dx_num = eval_numerical_gradient_array(lambda x: relu_forward(x)[0], x, dout)

_, cache = relu_forward(x)
dx = relu_backward(dout, cache)

# The error should be on the order of e-12
print('Testing relu_backward function:')
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing relu_backward function:
# dx error:  3.2756349136310288e-12

# %% [markdown]
# ## Теоретический вопрос 1
#
# Мы просили реализовать только ReLU, но в нейросетях можно использовать много разных функций активации, у каждой есть свои плюсы и минусы. Одна из частых проблем — исчезающие градиенты, когда во время обратного распространения градиент становится равным нулю или очень близким к нулю.
#
# Какие из перечисленных ниже функций страдают от этой проблемы? Если рассматривать функции в одномерном случае, то для каких входных значений это происходит?
#
# 1. `sigmoid`
# 2. `ReLU`
# 3. `Leaky RELU`
#
# ### Ваш ответ:
# > От проблемы исчезающих градиентов страдают сигмоида (sigmoid) и, при отрицательных входах, обычный ReLU.
# > Leaky ReLU практически не страдает от исчезающих градиентов.

# %% [markdown]
# # «Сэндвич»-слои
#
# В нейронных сетях часто встречаются типовые комбинации слоёв. Например, полносвязный слой часто сразу сопровождается ReLU. Чтобы не писать один и тот же код много раз, в файле `classifiers/layer_utils.py` определены составные слои.
#
# Сейчас посмотрите на функции `affine_relu_forward` и `affine_relu_backward`, а затем запустите следующую ячейку для численной проверки градиентов обратного прохода:

# %%
from classifiers.layer_utils import affine_relu_forward, affine_relu_backward
np.random.seed(231)
x = np.random.randn(2, 3, 4)
w = np.random.randn(12, 10)
b = np.random.randn(10)
dout = np.random.randn(2, 10)

out, cache = affine_relu_forward(x, w, b)
dx, dw, db = affine_relu_backward(dout, cache)

dx_num = eval_numerical_gradient_array(lambda x: affine_relu_forward(x, w, b)[0], x, dout)
dw_num = eval_numerical_gradient_array(lambda w: affine_relu_forward(x, w, b)[0], w, dout)
db_num = eval_numerical_gradient_array(lambda b: affine_relu_forward(x, w, b)[0], b, dout)

# Relative error should be around e-10 or less
print('Testing affine_relu_forward and affine_relu_backward:')
print('dx error: ', rel_error(dx_num, dx))
print('dw error: ', rel_error(dw_num, dw))
print('db error: ', rel_error(db_num, db))
# Out:
# Testing affine_relu_forward and affine_relu_backward:
# dx error:  2.299579177309368e-11
# dw error:  8.162011105764925e-11
# db error:  7.826724021458994e-12

# %% [markdown]
# # Слой потерь: Softmax
#
# Теперь реализуйте функцию потерь и градиент для softmax в функции `softmax_loss` в файле `classifiers/layers.py`.
#
# Корректность реализации можно проверить следующей ячейкой:

# %%
np.random.seed(231)
num_classes, num_inputs = 10, 50
x = 0.001 * np.random.randn(num_inputs, num_classes)
y = np.random.randint(num_classes, size=num_inputs)


dx_num = eval_numerical_gradient(lambda x: softmax_loss(x, y)[0], x, verbose=False)
loss, dx = softmax_loss(x, y)

# Test softmax_loss function. Loss should be close to 2.3 and dx error should be around e-8
print('\nTesting softmax_loss:')
print('loss: ', loss)
print('dx error: ', rel_error(dx_num, dx))
# Out:
# Testing softmax_loss:
# loss:  2.3025458445007376
# dx error:  8.234144091578429e-09

# %% [markdown]
# # Двухслойная сеть
#
# Откройте файл `classifiers/fc_net.py` и завершите реализацию класса `TwoLayerNet`. Внимательно прочитайте код, чтобы понять API. После этого можно запустить следующую ячейку для проверки реализации.

# %%
np.random.seed(231)
N, D, H, C = 3, 5, 50, 7
X = np.random.randn(N, D)
y = np.random.randint(C, size=N)

std = 1e-3
model = TwoLayerNet(input_dim=D, hidden_dim=H, num_classes=C, weight_scale=std)

print('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

print('Testing test-time forward pass ... ')
model.params['W1'] = np.linspace(-0.7, 0.3, num=D*H).reshape(D, H)
model.params['b1'] = np.linspace(-0.1, 0.9, num=H)
model.params['W2'] = np.linspace(-0.3, 0.4, num=H*C).reshape(H, C)
model.params['b2'] = np.linspace(-0.9, 0.1, num=C)
X = np.linspace(-5.5, 4.5, num=N*D).reshape(D, N).T
scores = model.loss(X)
correct_scores = np.asarray(
  [[11.53165108,  12.2917344,   13.05181771,  13.81190102,  14.57198434, 15.33206765,  16.09215096],
   [12.05769098,  12.74614105,  13.43459113,  14.1230412,   14.81149128, 15.49994135,  16.18839143],
   [12.58373087,  13.20054771,  13.81736455,  14.43418138,  15.05099822, 15.66781506,  16.2846319 ]])
scores_diff = np.abs(scores - correct_scores).sum()
assert scores_diff < 1e-6, 'Problem with test-time forward pass'

print('Testing training loss (no regularization)')
y = np.asarray([0, 5, 1])
loss, grads = model.loss(X, y)
correct_loss = 3.4702243556
assert abs(loss - correct_loss) < 1e-10, 'Problem with training-time loss'

model.reg = 1.0
loss, grads = model.loss(X, y)
correct_loss = 26.5948426952
assert abs(loss - correct_loss) < 1e-10, 'Problem with regularization loss'

# Errors should be around e-7 or less
for reg in [0.0, 0.7]:
  print('Running numeric gradient check with reg = ', reg)
  model.reg = reg
  loss, grads = model.loss(X, y)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False)
    print('%s relative error: %.2e' % (name, rel_error(grad_num, grads[name])))
# Out:
# Testing initialization ...
# Testing test-time forward pass ...
# Testing training loss (no regularization)
# Running numeric gradient check with reg =  0.0
# W1 relative error: 1.83e-08
# W2 relative error: 3.20e-10
# b1 relative error: 9.83e-09
# b2 relative error: 4.33e-10
# Running numeric gradient check with reg =  0.7
# W1 relative error: 2.53e-07
# W2 relative error: 2.85e-08
# b1 relative error: 1.56e-08
# b2 relative error: 9.09e-10

# %% [markdown]
# # Solver
#
# Откройте файл `utils/solver.py` и ознакомьтесь с его API. Затем с помощью объекта `Solver` обучите `TwoLayerNet`, чтобы добиться примерно точности на валидационной выборке как минимум более 35%. В качестве оптимизатора можно взять на данном уже реализованный в optim.py, либо написать свой

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10

model = TwoLayerNet(input_dim=input_size, hidden_dim=hidden_size, 
                    num_classes=num_classes, weight_scale=1e-3, reg=0.0)

from utils.optim import sgd, sgd_momentum

solver = Solver(model, data,
                update_rule='sgd_momentum',
                optim_config={
                    'learning_rate': 1e-3,
                    'momentum': 0.9
                },
                lr_decay=0.95,
                num_epochs=10, 
                batch_size=200,
                print_every=100,
                verbose=True)

solver.train()
# Out:
# (Iteration 1 / 2450) loss: 2.301725
# (Epoch 0 / 10) train acc: 0.187000; val_acc: 0.181000
# (Iteration 101 / 2450) loss: 1.967731
# (Iteration 201 / 2450) loss: 2.149349
# (Epoch 1 / 10) train acc: 0.305000; val_acc: 0.329000
# (Iteration 301 / 2450) loss: 8.944063
# (Iteration 401 / 2450) loss: 18.139582
# (Epoch 2 / 10) train acc: 0.172000; val_acc: 0.206000
# (Iteration 501 / 2450) loss: 19.341715
# (Iteration 601 / 2450) loss: 18.996327
# (Iteration 701 / 2450) loss: 17.384517
# (Epoch 3 / 10) train acc: 0.187000; val_acc: 0.172000
# (Iteration 801 / 2450) loss: 18.996327
# (Iteration 901 / 2450) loss: 19.111456
# (Epoch 4 / 10) train acc: 0.192000; val_acc: 0.193000
# (Iteration 1001 / 2450) loss: 18.420681
# (Iteration 1101 / 2450) loss: 18.305551
# (Iteration 1201 / 2450) loss: 18.535810
# (Epoch 5 / 10) train acc: 0.186000; val_acc: 0.167000
# (Iteration 1301 / 2450) loss: 19.226586
# (Iteration 1401 / 2450) loss: 18.535810
# (Epoch 6 / 10) train acc: 0.254000; val_acc: 0.244000
# (Iteration 1501 / 2450) loss: 19.111456
# (Iteration 1601 / 2450) loss: 18.305551
# (Iteration 1701 / 2450) loss: 18.075293
# (Epoch 7 / 10) train acc: 0.207000; val_acc: 0.201000
# (Iteration 1801 / 2450) loss: 17.845034
# (Iteration 1901 / 2450) loss: 19.352601
# (Epoch 8 / 10) train acc: 0.170000; val_acc: 0.197000
# (Iteration 2001 / 2450) loss: 18.420681
# (Iteration 2101 / 2450) loss: 19.917361
# (Iteration 2201 / 2450) loss: 16.808871
# (Epoch 9 / 10) train acc: 0.282000; val_acc: 0.270000
# (Iteration 2301 / 2450) loss: 17.981586
# (Iteration 2401 / 2450) loss: 17.384517
# (Epoch 10 / 10) train acc: 0.234000; val_acc: 0.250000

# %% [markdown]
# # Отладка обучения
#
# С параметрами по умолчанию точность на валидации должна получиться около `0.36`. Это не очень высокий результат.
#
# Один способ понять, что идёт не так, — построить графики функции потерь и точности на обучающей и валидационной выборках во время оптимизации.
#
# Другой способ — визуализировать веса, которые выучила сеть в первом слое. В задачах компьютерного зрения первый слой часто начинает выделять простые шаблоны: границы, цветовые контрасты, текстуры. Если веса выглядят как шум, это намекает на проблемы с настройкой обучения.

# %%
# Визуализация функции потерь и точности на train / val

plt.subplot(2, 1, 1)
plt.title('Функция потерь при обучении')
plt.plot(solver.loss_history, 'o')
plt.xlabel('Итерация')

plt.subplot(2, 1, 2)
plt.title('Точность')
plt.plot(solver.train_acc_history, '-o', label='train')
plt.plot(solver.val_acc_history, '-o', label='val')
plt.plot([0.5] * len(solver.val_acc_history), 'k--')
plt.xlabel('Эпоха')
plt.legend(loc='lower right')
plt.gcf().set_size_inches(15, 12)
plt.show()

# %%
from utils.vis_utils import visualize_grid

# Визуализация весов первого слоя сети
def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')
    plt.show()

show_net_weights(model)

# %% [markdown]
# # Подбор гиперпараметров
#
# **Что здесь не так?** По графикам выше видно, что функция потерь убывает почти линейно. Это часто говорит о том, что скорость обучения слишком мала. Кроме того, между обучающей и валидационной точностью почти нет разрыва, а значит, модель, скорее всего, имеет недостаточную ёмкость и её стоит увеличить.
#
# С другой стороны, слишком большая модель может начать переобучаться: тогда обучающая точность станет заметно выше валидационной. Ваша цель — подобрать такие гиперпараметры, чтобы получить качество выше `48%` на валидации.
# При выборе варьируемых гиперпараметров модно отталкиваться от параметров TwoLayerNet

# %%
best_model = None
best_val_acc = 0

# Подбор гиперпараметров
for hidden_size in [100, 200]:
    for learning_rate in [1e-3, 5e-4, 1e-4]:
        for reg in [0.0, 1e-4]:
            for weight_scale in [1e-4, 5e-5, 1e-5]:
                model = TwoLayerNet(
                    input_dim=input_size, 
                    hidden_dim=hidden_size,
                    num_classes=num_classes, 
                    weight_scale=weight_scale, 
                    reg=reg
                )
                
                solver = Solver(model, data,
                    update_rule='sgd_momentum',
                    optim_config={
                        'learning_rate': learning_rate,
                        'momentum': 0.9
                    },
                    lr_decay=0.95,
                    num_epochs=5, 
                    batch_size=200,
                    print_every=100,
                    verbose=True)
                
                solver.train()
                
                val_acc = solver.val_acc_history[-1]
                print(f'hidden={hidden_size}, lr={learning_rate}, reg={reg}, scale={weight_scale} -> val_acc={val_acc:.4f}')
                
                if val_acc > best_val_acc:
                    best_val_acc = val_acc
                    best_model = model

print(f'Best validation accuracy: {best_val_acc:.4f}')
# Out:
# (Iteration 1 / 1225) loss: 2.302560
# (Epoch 0 / 5) train acc: 0.156000; val_acc: 0.154000
# (Iteration 101 / 1225) loss: 1.795864
# (Iteration 201 / 1225) loss: 2.067065
# (Epoch 1 / 5) train acc: 0.367000; val_acc: 0.359000
# (Iteration 301 / 1225) loss: 14.914181
# (Iteration 401 / 1225) loss: 18.650939
# (Epoch 2 / 5) train acc: 0.208000; val_acc: 0.188000
# (Iteration 501 / 1225) loss: 18.305551
# (Iteration 601 / 1225) loss: 19.571973
# (Iteration 701 / 1225) loss: 18.305551
# (Epoch 3 / 5) train acc: 0.178000; val_acc: 0.213000
# (Iteration 801 / 1225) loss: 17.269388
# (Iteration 901 / 1225) loss: 20.262749
# (Epoch 4 / 5) train acc: 0.214000; val_acc: 0.202000
# (Iteration 1001 / 1225) loss: 18.996327
# (Iteration 1101 / 1225) loss: 17.499647
# (Iteration 1201 / 1225) loss: 17.729905
# (Epoch 5 / 5) train acc: 0.234000; val_acc: 0.232000
# hidden=100, lr=0.001, reg=0.0, scale=0.0001 -> val_acc=0.2320
# (Iteration 1 / 1225) loss: 2.302590
# (Epoch 0 / 5) train acc: 0.117000; val_acc: 0.122000
# (Iteration 101 / 1225) loss: 2.003720
# (Iteration 201 / 1225) loss: 1.988119
# (Epoch 1 / 5) train acc: 0.321000; val_acc: 0.324000
# (Iteration 301 / 1225) loss: 10.245140
# (Iteration 401 / 1225) loss: 18.650939
# (Epoch 2 / 5) train acc: 0.181000; val_acc: 0.173000
# (Iteration 501 / 1225) loss: 17.960164
# (Iteration 601 / 1225) loss: 19.111456
# (Iteration 701 / 1225) loss: 20.262749
# (Epoch 3 / 5) train acc: 0.192000; val_acc: 0.199000
# (Iteration 801 / 1225) loss: 18.305551
# (Iteration 901 / 1225) loss: 18.881198
# (Epoch 4 / 5) train acc: 0.234000; val_acc: 0.225000
# (Iteration 1001 / 1225) loss: 17.499647
# (Iteration 1101 / 1225) loss: 17.269388
# (Iteration 1201 / 1225) loss: 19.341715
# (Epoch 5 / 5) train acc: 0.187000; val_acc: 0.188000
# hidden=100, lr=0.001, reg=0.0, scale=5e-05 -> val_acc=0.1880
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.101000; val_acc: 0.104000
# (Iteration 101 / 1225) loss: 1.833079
# (Iteration 201 / 1225) loss: 2.439334
# (Epoch 1 / 5) train acc: 0.270000; val_acc: 0.278000
# (Iteration 301 / 1225) loss: 18.826199
# (Iteration 401 / 1225) loss: 19.571973
# (Epoch 2 / 5) train acc: 0.220000; val_acc: 0.211000
# (Iteration 501 / 1225) loss: 18.996327
# (Iteration 601 / 1225) loss: 18.650939
# (Iteration 701 / 1225) loss: 19.456844
# (Epoch 3 / 5) train acc: 0.243000; val_acc: 0.246000
# (Iteration 801 / 1225) loss: 19.341715
# (Iteration 901 / 1225) loss: 18.535810
# (Epoch 4 / 5) train acc: 0.184000; val_acc: 0.184000
# (Iteration 1001 / 1225) loss: 18.996327
# (Iteration 1101 / 1225) loss: 19.571973
# (Iteration 1201 / 1225) loss: 18.881198
# (Epoch 5 / 5) train acc: 0.208000; val_acc: 0.185000
# hidden=100, lr=0.001, reg=0.0, scale=1e-05 -> val_acc=0.1850
# (Iteration 1 / 1225) loss: 2.302555
# (Epoch 0 / 5) train acc: 0.140000; val_acc: 0.141000
# (Iteration 101 / 1225) loss: 1.884183
# (Iteration 201 / 1225) loss: 2.176983
# (Epoch 1 / 5) train acc: 0.304000; val_acc: 0.310000
# (Iteration 301 / 1225) loss: 2.590219
# (Iteration 401 / 1225) loss: 18.884130
# (Epoch 2 / 5) train acc: 0.189000; val_acc: 0.168000
# (Iteration 501 / 1225) loss: 56.722691
# (Iteration 601 / 1225) loss: 34361.466209
# (Iteration 701 / 1225) loss: 13712458.088373
# (Epoch 3 / 5) train acc: 0.159000; val_acc: 0.180000
# (Iteration 801 / 1225) loss: 8466652998.281415
# (Iteration 901 / 1225) loss: 5111535563591.416992
# (Epoch 4 / 5) train acc: 0.195000; val_acc: 0.185000
# (Iteration 1001 / 1225) loss: 1989631372568304.500000
# (Iteration 1101 / 1225) loss: 50199995049378440.000000
# (Iteration 1201 / 1225) loss: 580692740347776768.000000
# (Epoch 5 / 5) train acc: 0.180000; val_acc: 0.185000
# hidden=100, lr=0.001, reg=0.0001, scale=0.0001 -> val_acc=0.1850
# (Iteration 1 / 1225) loss: 2.302584
# (Epoch 0 / 5) train acc: 0.141000; val_acc: 0.140000
# (Iteration 101 / 1225) loss: 2.000739
# (Iteration 201 / 1225) loss: 1.796349
# (Epoch 1 / 5) train acc: 0.312000; val_acc: 0.329000
# (Iteration 301 / 1225) loss: 2.176952
# (Iteration 401 / 1225) loss: 1.783196
# (Epoch 2 / 5) train acc: 0.396000; val_acc: 0.377000
# (Iteration 501 / 1225) loss: 2.090038
# (Iteration 601 / 1225) loss: 1.938970
# (Iteration 701 / 1225) loss: 1.828556
# (Epoch 3 / 5) train acc: 0.360000; val_acc: 0.348000
# (Iteration 801 / 1225) loss: 2.095852
# (Iteration 901 / 1225) loss: 2.007237
# (Epoch 4 / 5) train acc: 0.355000; val_acc: 0.353000
# (Iteration 1001 / 1225) loss: 1.988190
# (Iteration 1101 / 1225) loss: 2.128358
# (Iteration 1201 / 1225) loss: 1.794649
# (Epoch 5 / 5) train acc: 0.383000; val_acc: 0.367000
# hidden=100, lr=0.001, reg=0.0001, scale=5e-05 -> val_acc=0.3670
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.115000; val_acc: 0.078000
# (Iteration 101 / 1225) loss: 1.789597
# (Iteration 201 / 1225) loss: 2.418373
# (Epoch 1 / 5) train acc: 0.181000; val_acc: 0.193000
# (Iteration 301 / 1225) loss: 19.472062
# (Iteration 401 / 1225) loss: 28.539178
# (Epoch 2 / 5) train acc: 0.219000; val_acc: 0.192000
# (Iteration 501 / 1225) loss: 9646.736186
# (Iteration 601 / 1225) loss: 1837853.778325
# (Iteration 701 / 1225) loss: 830113488.840899
# (Epoch 3 / 5) train acc: 0.165000; val_acc: 0.182000
# (Iteration 801 / 1225) loss: 117350907450.375763
# (Iteration 901 / 1225) loss: 18426110060712.527344
# (Epoch 4 / 5) train acc: 0.124000; val_acc: 0.164000
# (Iteration 1001 / 1225) loss: 9018239486950392.000000
# (Iteration 1101 / 1225) loss: 569185661788185408.000000
# (Iteration 1201 / 1225) loss: 25015516358666203136.000000
# (Epoch 5 / 5) train acc: 0.150000; val_acc: 0.196000
# hidden=100, lr=0.001, reg=0.0001, scale=1e-05 -> val_acc=0.1960
# (Iteration 1 / 1225) loss: 2.302582
# (Epoch 0 / 5) train acc: 0.103000; val_acc: 0.118000
# (Iteration 101 / 1225) loss: 1.770278
# (Iteration 201 / 1225) loss: 1.658398
# (Epoch 1 / 5) train acc: 0.405000; val_acc: 0.412000
# (Iteration 301 / 1225) loss: 1.595610
# (Iteration 401 / 1225) loss: 1.477113
# (Epoch 2 / 5) train acc: 0.427000; val_acc: 0.418000
# (Iteration 501 / 1225) loss: 1.520462
# (Iteration 601 / 1225) loss: 1.331653
# (Iteration 701 / 1225) loss: 1.589897
# (Epoch 3 / 5) train acc: 0.503000; val_acc: 0.451000
# (Iteration 801 / 1225) loss: 1.457796
# (Iteration 901 / 1225) loss: 1.422242
# (Epoch 4 / 5) train acc: 0.508000; val_acc: 0.482000
# (Iteration 1001 / 1225) loss: 1.357660
# (Iteration 1101 / 1225) loss: 1.547797
# (Iteration 1201 / 1225) loss: 1.504124
# (Epoch 5 / 5) train acc: 0.498000; val_acc: 0.487000
# hidden=100, lr=0.0005, reg=0.0, scale=0.0001 -> val_acc=0.4870
# (Iteration 1 / 1225) loss: 2.302583
# (Epoch 0 / 5) train acc: 0.120000; val_acc: 0.099000
# (Iteration 101 / 1225) loss: 1.758840
# (Iteration 201 / 1225) loss: 1.608061
# (Epoch 1 / 5) train acc: 0.412000; val_acc: 0.439000
# (Iteration 301 / 1225) loss: 1.645567
# (Iteration 401 / 1225) loss: 1.576244
# (Epoch 2 / 5) train acc: 0.446000; val_acc: 0.439000
# (Iteration 501 / 1225) loss: 1.537110
# (Iteration 601 / 1225) loss: 1.418111
# (Iteration 701 / 1225) loss: 1.496373
# (Epoch 3 / 5) train acc: 0.523000; val_acc: 0.454000
# (Iteration 801 / 1225) loss: 1.400131
# (Iteration 901 / 1225) loss: 1.273943
# (Epoch 4 / 5) train acc: 0.487000; val_acc: 0.454000
# (Iteration 1001 / 1225) loss: 1.397938
# (Iteration 1101 / 1225) loss: 1.314304
# (Iteration 1201 / 1225) loss: 1.456376
# (Epoch 5 / 5) train acc: 0.503000; val_acc: 0.460000
# hidden=100, lr=0.0005, reg=0.0, scale=5e-05 -> val_acc=0.4600
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.119000; val_acc: 0.128000
# (Iteration 101 / 1225) loss: 1.738936
# (Iteration 201 / 1225) loss: 1.573953
# (Epoch 1 / 5) train acc: 0.404000; val_acc: 0.421000
# (Iteration 301 / 1225) loss: 1.523414
# (Iteration 401 / 1225) loss: 1.612647
# (Epoch 2 / 5) train acc: 0.466000; val_acc: 0.457000
# (Iteration 501 / 1225) loss: 1.615147
# (Iteration 601 / 1225) loss: 1.564653
# (Iteration 701 / 1225) loss: 1.448779
# (Epoch 3 / 5) train acc: 0.461000; val_acc: 0.438000
# (Iteration 801 / 1225) loss: 1.427415
# (Iteration 901 / 1225) loss: 1.541766
# (Epoch 4 / 5) train acc: 0.519000; val_acc: 0.473000
# (Iteration 1001 / 1225) loss: 1.269222
# (Iteration 1101 / 1225) loss: 1.706671
# (Iteration 1201 / 1225) loss: 1.386205
# (Epoch 5 / 5) train acc: 0.509000; val_acc: 0.489000
# hidden=100, lr=0.0005, reg=0.0, scale=1e-05 -> val_acc=0.4890
# (Iteration 1 / 1225) loss: 2.302575
# (Epoch 0 / 5) train acc: 0.113000; val_acc: 0.105000
# (Iteration 101 / 1225) loss: 1.743300
# (Iteration 201 / 1225) loss: 1.566086
# (Epoch 1 / 5) train acc: 0.423000; val_acc: 0.412000
# (Iteration 301 / 1225) loss: 1.659888
# (Iteration 401 / 1225) loss: 1.613767
# (Epoch 2 / 5) train acc: 0.455000; val_acc: 0.466000
# (Iteration 501 / 1225) loss: 1.359414
# (Iteration 601 / 1225) loss: 1.491510
# (Iteration 701 / 1225) loss: 1.623678
# (Epoch 3 / 5) train acc: 0.487000; val_acc: 0.441000
# (Iteration 801 / 1225) loss: 1.383711
# (Iteration 901 / 1225) loss: 1.365887
# (Epoch 4 / 5) train acc: 0.502000; val_acc: 0.465000
# (Iteration 1001 / 1225) loss: 1.327560
# (Iteration 1101 / 1225) loss: 1.401866
# (Iteration 1201 / 1225) loss: 1.477110
# (Epoch 5 / 5) train acc: 0.523000; val_acc: 0.470000
# hidden=100, lr=0.0005, reg=0.0001, scale=0.0001 -> val_acc=0.4700
# (Iteration 1 / 1225) loss: 2.302577
# (Epoch 0 / 5) train acc: 0.119000; val_acc: 0.122000
# (Iteration 101 / 1225) loss: 1.718141
# (Iteration 201 / 1225) loss: 1.688655
# (Epoch 1 / 5) train acc: 0.471000; val_acc: 0.429000
# (Iteration 301 / 1225) loss: 1.573825
# (Iteration 401 / 1225) loss: 1.527126
# (Epoch 2 / 5) train acc: 0.434000; val_acc: 0.423000
# (Iteration 501 / 1225) loss: 1.615603
# (Iteration 601 / 1225) loss: 1.554227
# (Iteration 701 / 1225) loss: 1.375132
# (Epoch 3 / 5) train acc: 0.464000; val_acc: 0.431000
# (Iteration 801 / 1225) loss: 1.433681
# (Iteration 901 / 1225) loss: 1.447022
# (Epoch 4 / 5) train acc: 0.538000; val_acc: 0.482000
# (Iteration 1001 / 1225) loss: 1.430676
# (Iteration 1101 / 1225) loss: 1.380533
# (Iteration 1201 / 1225) loss: 1.512691
# (Epoch 5 / 5) train acc: 0.481000; val_acc: 0.473000
# hidden=100, lr=0.0005, reg=0.0001, scale=5e-05 -> val_acc=0.4730
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.103000; val_acc: 0.107000
# (Iteration 101 / 1225) loss: 1.869733
# (Iteration 201 / 1225) loss: 1.733066
# (Epoch 1 / 5) train acc: 0.417000; val_acc: 0.424000
# (Iteration 301 / 1225) loss: 1.499617
# (Iteration 401 / 1225) loss: 1.609687
# (Epoch 2 / 5) train acc: 0.473000; val_acc: 0.455000
# (Iteration 501 / 1225) loss: 1.394742
# (Iteration 601 / 1225) loss: 1.475725
# (Iteration 701 / 1225) loss: 1.374276
# (Epoch 3 / 5) train acc: 0.443000; val_acc: 0.434000
# (Iteration 801 / 1225) loss: 1.340232
# (Iteration 901 / 1225) loss: 1.735387
# (Epoch 4 / 5) train acc: 0.512000; val_acc: 0.432000
# (Iteration 1001 / 1225) loss: 1.487015
# (Iteration 1101 / 1225) loss: 1.240246
# (Iteration 1201 / 1225) loss: 1.369297
# (Epoch 5 / 5) train acc: 0.509000; val_acc: 0.483000
# hidden=100, lr=0.0005, reg=0.0001, scale=1e-05 -> val_acc=0.4830
# (Iteration 1 / 1225) loss: 2.302563
# (Epoch 0 / 5) train acc: 0.091000; val_acc: 0.116000
# (Iteration 101 / 1225) loss: 1.957459
# (Iteration 201 / 1225) loss: 1.806621
# (Epoch 1 / 5) train acc: 0.377000; val_acc: 0.379000
# (Iteration 301 / 1225) loss: 1.664351
# (Iteration 401 / 1225) loss: 1.607317
# (Epoch 2 / 5) train acc: 0.436000; val_acc: 0.436000
# (Iteration 501 / 1225) loss: 1.665491
# (Iteration 601 / 1225) loss: 1.543295
# (Iteration 701 / 1225) loss: 1.493316
# (Epoch 3 / 5) train acc: 0.489000; val_acc: 0.464000
# (Iteration 801 / 1225) loss: 1.535085
# (Iteration 901 / 1225) loss: 1.572449
# (Epoch 4 / 5) train acc: 0.494000; val_acc: 0.470000
# (Iteration 1001 / 1225) loss: 1.360400
# (Iteration 1101 / 1225) loss: 1.484800
# (Iteration 1201 / 1225) loss: 1.447919
# (Epoch 5 / 5) train acc: 0.530000; val_acc: 0.476000
# hidden=100, lr=0.0001, reg=0.0, scale=0.0001 -> val_acc=0.4760
# (Iteration 1 / 1225) loss: 2.302586
# (Epoch 0 / 5) train acc: 0.106000; val_acc: 0.105000
# (Iteration 101 / 1225) loss: 2.080574
# (Iteration 201 / 1225) loss: 1.902980
# (Epoch 1 / 5) train acc: 0.374000; val_acc: 0.377000
# (Iteration 301 / 1225) loss: 1.721435
# (Iteration 401 / 1225) loss: 1.633826
# (Epoch 2 / 5) train acc: 0.458000; val_acc: 0.441000
# (Iteration 501 / 1225) loss: 1.563083
# (Iteration 601 / 1225) loss: 1.428864
# (Iteration 701 / 1225) loss: 1.299451
# (Epoch 3 / 5) train acc: 0.501000; val_acc: 0.466000
# (Iteration 801 / 1225) loss: 1.372140
# (Iteration 901 / 1225) loss: 1.381582
# (Epoch 4 / 5) train acc: 0.526000; val_acc: 0.473000
# (Iteration 1001 / 1225) loss: 1.409231
# (Iteration 1101 / 1225) loss: 1.436537
# (Iteration 1201 / 1225) loss: 1.269332
# (Epoch 5 / 5) train acc: 0.514000; val_acc: 0.494000
# hidden=100, lr=0.0001, reg=0.0, scale=5e-05 -> val_acc=0.4940
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.138000; val_acc: 0.117000
# (Iteration 101 / 1225) loss: 2.152689
# (Iteration 201 / 1225) loss: 1.913139
# (Epoch 1 / 5) train acc: 0.366000; val_acc: 0.333000
# (Iteration 301 / 1225) loss: 1.651853
# (Iteration 401 / 1225) loss: 1.639150
# (Epoch 2 / 5) train acc: 0.440000; val_acc: 0.430000
# (Iteration 501 / 1225) loss: 1.733762
# (Iteration 601 / 1225) loss: 1.593287
# (Iteration 701 / 1225) loss: 1.450081
# (Epoch 3 / 5) train acc: 0.459000; val_acc: 0.465000
# (Iteration 801 / 1225) loss: 1.569527
# (Iteration 901 / 1225) loss: 1.400577
# (Epoch 4 / 5) train acc: 0.481000; val_acc: 0.489000
# (Iteration 1001 / 1225) loss: 1.409524
# (Iteration 1101 / 1225) loss: 1.355352
# (Iteration 1201 / 1225) loss: 1.346343
# (Epoch 5 / 5) train acc: 0.541000; val_acc: 0.484000
# hidden=100, lr=0.0001, reg=0.0, scale=1e-05 -> val_acc=0.4840
# (Iteration 1 / 1225) loss: 2.302571
# (Epoch 0 / 5) train acc: 0.107000; val_acc: 0.132000
# (Iteration 101 / 1225) loss: 2.030979
# (Iteration 201 / 1225) loss: 1.824300
# (Epoch 1 / 5) train acc: 0.394000; val_acc: 0.390000
# (Iteration 301 / 1225) loss: 1.795936
# (Iteration 401 / 1225) loss: 1.622821
# (Epoch 2 / 5) train acc: 0.476000; val_acc: 0.445000
# (Iteration 501 / 1225) loss: 1.599640
# (Iteration 601 / 1225) loss: 1.459360
# (Iteration 701 / 1225) loss: 1.432401
# (Epoch 3 / 5) train acc: 0.475000; val_acc: 0.479000
# (Iteration 801 / 1225) loss: 1.374929
# (Iteration 901 / 1225) loss: 1.445016
# (Epoch 4 / 5) train acc: 0.520000; val_acc: 0.475000
# (Iteration 1001 / 1225) loss: 1.429835
# (Iteration 1101 / 1225) loss: 1.466871
# (Iteration 1201 / 1225) loss: 1.244096
# (Epoch 5 / 5) train acc: 0.517000; val_acc: 0.491000
# hidden=100, lr=0.0001, reg=0.0001, scale=0.0001 -> val_acc=0.4910
# (Iteration 1 / 1225) loss: 2.302587
# (Epoch 0 / 5) train acc: 0.093000; val_acc: 0.080000
# (Iteration 101 / 1225) loss: 1.978654
# (Iteration 201 / 1225) loss: 1.830955
# (Epoch 1 / 5) train acc: 0.399000; val_acc: 0.369000
# (Iteration 301 / 1225) loss: 1.775669
# (Iteration 401 / 1225) loss: 1.545121
# (Epoch 2 / 5) train acc: 0.439000; val_acc: 0.449000
# (Iteration 501 / 1225) loss: 1.557015
# (Iteration 601 / 1225) loss: 1.454128
# (Iteration 701 / 1225) loss: 1.408284
# (Epoch 3 / 5) train acc: 0.512000; val_acc: 0.466000
# (Iteration 801 / 1225) loss: 1.529181
# (Iteration 901 / 1225) loss: 1.437449
# (Epoch 4 / 5) train acc: 0.492000; val_acc: 0.474000
# (Iteration 1001 / 1225) loss: 1.479716
# (Iteration 1101 / 1225) loss: 1.283948
# (Iteration 1201 / 1225) loss: 1.367467
# (Epoch 5 / 5) train acc: 0.522000; val_acc: 0.495000
# hidden=100, lr=0.0001, reg=0.0001, scale=5e-05 -> val_acc=0.4950
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.087000; val_acc: 0.080000
# (Iteration 101 / 1225) loss: 2.158090
# (Iteration 201 / 1225) loss: 1.838300
# (Epoch 1 / 5) train acc: 0.319000; val_acc: 0.355000
# (Iteration 301 / 1225) loss: 1.702555
# (Iteration 401 / 1225) loss: 1.726156
# (Epoch 2 / 5) train acc: 0.411000; val_acc: 0.434000
# (Iteration 501 / 1225) loss: 1.633918
# (Iteration 601 / 1225) loss: 1.514156
# (Iteration 701 / 1225) loss: 1.564540
# (Epoch 3 / 5) train acc: 0.481000; val_acc: 0.460000
# (Iteration 801 / 1225) loss: 1.424923
# (Iteration 901 / 1225) loss: 1.427183
# (Epoch 4 / 5) train acc: 0.512000; val_acc: 0.472000
# (Iteration 1001 / 1225) loss: 1.395661
# (Iteration 1101 / 1225) loss: 1.505554
# (Iteration 1201 / 1225) loss: 1.397694
# (Epoch 5 / 5) train acc: 0.503000; val_acc: 0.494000
# hidden=100, lr=0.0001, reg=0.0001, scale=1e-05 -> val_acc=0.4940
# (Iteration 1 / 1225) loss: 2.302595
# (Epoch 0 / 5) train acc: 0.148000; val_acc: 0.146000
# (Iteration 101 / 1225) loss: 1.785487
# (Iteration 201 / 1225) loss: 2.158326
# (Epoch 1 / 5) train acc: 0.334000; val_acc: 0.334000
# (Iteration 301 / 1225) loss: 4.284913
# (Iteration 401 / 1225) loss: 19.341715
# (Epoch 2 / 5) train acc: 0.209000; val_acc: 0.215000
# (Iteration 501 / 1225) loss: 19.456844
# (Iteration 601 / 1225) loss: 19.226586
# (Iteration 701 / 1225) loss: 19.456844
# (Epoch 3 / 5) train acc: 0.122000; val_acc: 0.116000
# (Iteration 801 / 1225) loss: 20.147620
# (Iteration 901 / 1225) loss: 19.687103
# (Epoch 4 / 5) train acc: 0.202000; val_acc: 0.209000
# (Iteration 1001 / 1225) loss: 18.535810
# (Iteration 1101 / 1225) loss: 18.766069
# (Iteration 1201 / 1225) loss: 19.571973
# (Epoch 5 / 5) train acc: 0.219000; val_acc: 0.234000
# hidden=200, lr=0.001, reg=0.0, scale=0.0001 -> val_acc=0.2340
# (Iteration 1 / 1225) loss: 2.302582
# (Epoch 0 / 5) train acc: 0.137000; val_acc: 0.149000
# (Iteration 101 / 1225) loss: 2.145005
# (Iteration 201 / 1225) loss: 2.372930
# (Epoch 1 / 5) train acc: 0.304000; val_acc: 0.325000
# (Iteration 301 / 1225) loss: 2.189225
# (Iteration 401 / 1225) loss: 15.293691
# (Epoch 2 / 5) train acc: 0.165000; val_acc: 0.172000
# (Iteration 501 / 1225) loss: 19.456844
# (Iteration 601 / 1225) loss: 17.729905
# (Iteration 701 / 1225) loss: 17.845034
# (Epoch 3 / 5) train acc: 0.172000; val_acc: 0.174000
# (Iteration 801 / 1225) loss: 17.729905
# (Iteration 901 / 1225) loss: 18.190422
# (Epoch 4 / 5) train acc: 0.225000; val_acc: 0.232000
# (Iteration 1001 / 1225) loss: 18.881198
# (Iteration 1101 / 1225) loss: 18.420681
# (Iteration 1201 / 1225) loss: 20.493007
# (Epoch 5 / 5) train acc: 0.179000; val_acc: 0.190000
# hidden=200, lr=0.001, reg=0.0, scale=5e-05 -> val_acc=0.1900
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.114000; val_acc: 0.085000
# (Iteration 101 / 1225) loss: 1.800071
# (Iteration 201 / 1225) loss: 2.055835
# (Epoch 1 / 5) train acc: 0.344000; val_acc: 0.352000
# (Iteration 301 / 1225) loss: 2.791160
# (Iteration 401 / 1225) loss: 2.269816
# (Epoch 2 / 5) train acc: 0.356000; val_acc: 0.345000
# (Iteration 501 / 1225) loss: 6.272014
# (Iteration 601 / 1225) loss: 17.729905
# (Iteration 701 / 1225) loss: 19.802232
# (Epoch 3 / 5) train acc: 0.174000; val_acc: 0.202000
# (Iteration 801 / 1225) loss: 19.111456
# (Iteration 901 / 1225) loss: 18.650939
# (Epoch 4 / 5) train acc: 0.177000; val_acc: 0.193000
# (Iteration 1001 / 1225) loss: 19.917361
# (Iteration 1101 / 1225) loss: 20.032490
# (Iteration 1201 / 1225) loss: 18.420681
# (Epoch 5 / 5) train acc: 0.193000; val_acc: 0.189000
# hidden=200, lr=0.001, reg=0.0, scale=1e-05 -> val_acc=0.1890
# (Iteration 1 / 1225) loss: 2.302551
# (Epoch 0 / 5) train acc: 0.165000; val_acc: 0.176000
# (Iteration 101 / 1225) loss: 1.861873
# (Iteration 201 / 1225) loss: 2.254228
# (Epoch 1 / 5) train acc: 0.325000; val_acc: 0.323000
# (Iteration 301 / 1225) loss: 3.201398
# (Iteration 401 / 1225) loss: 18.284600
# (Epoch 2 / 5) train acc: 0.178000; val_acc: 0.148000
# (Iteration 501 / 1225) loss: 128.586357
# (Iteration 601 / 1225) loss: 448428.420429
# (Iteration 701 / 1225) loss: 1641695219.698819
# (Epoch 3 / 5) train acc: 0.166000; val_acc: 0.144000
# (Iteration 801 / 1225) loss: 2345230941485.645020
# (Iteration 901 / 1225) loss: 1608303411934442.000000
# (Epoch 4 / 5) train acc: 0.269000; val_acc: 0.258000
# (Iteration 1001 / 1225) loss: 1391208745788059136.000000
# (Iteration 1101 / 1225) loss: 146783774487417176064.000000
# (Iteration 1201 / 1225) loss: 28916702230027528306688.000000
# (Epoch 5 / 5) train acc: 0.121000; val_acc: 0.128000
# hidden=200, lr=0.001, reg=0.0001, scale=0.0001 -> val_acc=0.1280
# (Iteration 1 / 1225) loss: 2.302581
# (Epoch 0 / 5) train acc: 0.137000; val_acc: 0.134000
# (Iteration 101 / 1225) loss: 1.948384
# (Iteration 201 / 1225) loss: 18.346286
# (Epoch 1 / 5) train acc: 0.179000; val_acc: 0.170000
# (Iteration 301 / 1225) loss: 330.959922
# (Iteration 401 / 1225) loss: 6138295.402694
# (Epoch 2 / 5) train acc: 0.186000; val_acc: 0.199000
# (Iteration 501 / 1225) loss: 135924637622.420914
# (Iteration 601 / 1225) loss: 252559215198279.218750
# (Iteration 701 / 1225) loss: 925573442093653120.000000
# (Epoch 3 / 5) train acc: 0.191000; val_acc: 0.194000
# (Iteration 801 / 1225) loss: 2988644257385863970816.000000
# (Iteration 901 / 1225) loss: 1257289681203491330064384.000000
# (Epoch 4 / 5) train acc: 0.136000; val_acc: 0.143000
# (Iteration 1001 / 1225) loss: 3863713817567097608829140992.000000
# (Iteration 1101 / 1225) loss: 783618269223846343191371448320.000000
# (Iteration 1201 / 1225) loss: 220925795357933771407441914757120.000000
# (Epoch 5 / 5) train acc: 0.239000; val_acc: 0.238000
# hidden=200, lr=0.001, reg=0.0001, scale=5e-05 -> val_acc=0.2380
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.097000; val_acc: 0.103000
# (Iteration 101 / 1225) loss: 1.981638
# (Iteration 201 / 1225) loss: 2.109054
# (Epoch 1 / 5) train acc: 0.341000; val_acc: 0.345000
# (Iteration 301 / 1225) loss: 2.304184
# (Iteration 401 / 1225) loss: 19.037079
# (Epoch 2 / 5) train acc: 0.190000; val_acc: 0.174000
# (Iteration 501 / 1225) loss: 371.680093
# (Iteration 601 / 1225) loss: 611182.979744
# (Iteration 701 / 1225) loss: 5203679777.718539
# (Epoch 3 / 5) train acc: 0.198000; val_acc: 0.196000
# (Iteration 801 / 1225) loss: 2628608477860.610352
# (Iteration 901 / 1225) loss: 698804779357409.375000
# (Epoch 4 / 5) train acc: 0.206000; val_acc: 0.187000
# (Iteration 1001 / 1225) loss: 350271834178173568.000000
# (Iteration 1101 / 1225) loss: 124060222780267872256.000000
# (Iteration 1201 / 1225) loss: 88157073915679193694208.000000
# (Epoch 5 / 5) train acc: 0.238000; val_acc: 0.222000
# hidden=200, lr=0.001, reg=0.0001, scale=1e-05 -> val_acc=0.2220
# (Iteration 1 / 1225) loss: 2.302619
# (Epoch 0 / 5) train acc: 0.132000; val_acc: 0.131000
# (Iteration 101 / 1225) loss: 1.558956
# (Iteration 201 / 1225) loss: 1.575613
# (Epoch 1 / 5) train acc: 0.464000; val_acc: 0.415000
# (Iteration 301 / 1225) loss: 1.631866
# (Iteration 401 / 1225) loss: 1.488891
# (Epoch 2 / 5) train acc: 0.444000; val_acc: 0.450000
# (Iteration 501 / 1225) loss: 1.708856
# (Iteration 601 / 1225) loss: 1.373369
# (Iteration 701 / 1225) loss: 1.487637
# (Epoch 3 / 5) train acc: 0.498000; val_acc: 0.472000
# (Iteration 801 / 1225) loss: 1.388059
# (Iteration 901 / 1225) loss: 1.376156
# (Epoch 4 / 5) train acc: 0.518000; val_acc: 0.454000
# (Iteration 1001 / 1225) loss: 1.337961
# (Iteration 1101 / 1225) loss: 1.278248
# (Iteration 1201 / 1225) loss: 1.346950
# (Epoch 5 / 5) train acc: 0.498000; val_acc: 0.450000
# hidden=200, lr=0.0005, reg=0.0, scale=0.0001 -> val_acc=0.4500
# (Iteration 1 / 1225) loss: 2.302578
# (Epoch 0 / 5) train acc: 0.098000; val_acc: 0.136000
# (Iteration 101 / 1225) loss: 1.738481
# (Iteration 201 / 1225) loss: 1.617654
# (Epoch 1 / 5) train acc: 0.447000; val_acc: 0.419000
# (Iteration 301 / 1225) loss: 1.582239
# (Iteration 401 / 1225) loss: 1.625740
# (Epoch 2 / 5) train acc: 0.445000; val_acc: 0.441000
# (Iteration 501 / 1225) loss: 1.556381
# (Iteration 601 / 1225) loss: 1.385298
# (Iteration 701 / 1225) loss: 1.386155
# (Epoch 3 / 5) train acc: 0.477000; val_acc: 0.445000
# (Iteration 801 / 1225) loss: 1.524208
# (Iteration 901 / 1225) loss: 1.444111
# (Epoch 4 / 5) train acc: 0.581000; val_acc: 0.493000
# (Iteration 1001 / 1225) loss: 1.396651
# (Iteration 1101 / 1225) loss: 1.583255
# (Iteration 1201 / 1225) loss: 1.388131
# (Epoch 5 / 5) train acc: 0.563000; val_acc: 0.479000
# hidden=200, lr=0.0005, reg=0.0, scale=5e-05 -> val_acc=0.4790
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.101000; val_acc: 0.079000
# (Iteration 101 / 1225) loss: 1.759569
# (Iteration 201 / 1225) loss: 1.584998
# (Epoch 1 / 5) train acc: 0.434000; val_acc: 0.431000
# (Iteration 301 / 1225) loss: 1.811416
# (Iteration 401 / 1225) loss: 1.485572
# (Epoch 2 / 5) train acc: 0.466000; val_acc: 0.458000
# (Iteration 501 / 1225) loss: 1.591603
# (Iteration 601 / 1225) loss: 1.507965
# (Iteration 701 / 1225) loss: 1.567519
# (Epoch 3 / 5) train acc: 0.511000; val_acc: 0.462000
# (Iteration 801 / 1225) loss: 1.568278
# (Iteration 901 / 1225) loss: 1.304248
# (Epoch 4 / 5) train acc: 0.507000; val_acc: 0.454000
# (Iteration 1001 / 1225) loss: 1.537918
# (Iteration 1101 / 1225) loss: 1.391805
# (Iteration 1201 / 1225) loss: 1.510052
# (Epoch 5 / 5) train acc: 0.541000; val_acc: 0.504000
# hidden=200, lr=0.0005, reg=0.0, scale=1e-05 -> val_acc=0.5040
# (Iteration 1 / 1225) loss: 2.302555
# (Epoch 0 / 5) train acc: 0.128000; val_acc: 0.128000
# (Iteration 101 / 1225) loss: 1.752064
# (Iteration 201 / 1225) loss: 1.649900
# (Epoch 1 / 5) train acc: 0.412000; val_acc: 0.421000
# (Iteration 301 / 1225) loss: 1.679807
# (Iteration 401 / 1225) loss: 1.428670
# (Epoch 2 / 5) train acc: 0.472000; val_acc: 0.452000
# (Iteration 501 / 1225) loss: 1.454026
# (Iteration 601 / 1225) loss: 1.541793
# (Iteration 701 / 1225) loss: 1.541581
# (Epoch 3 / 5) train acc: 0.490000; val_acc: 0.469000
# (Iteration 801 / 1225) loss: 1.313829
# (Iteration 901 / 1225) loss: 1.431956
# (Epoch 4 / 5) train acc: 0.510000; val_acc: 0.472000
# (Iteration 1001 / 1225) loss: 1.435132
# (Iteration 1101 / 1225) loss: 1.400602
# (Iteration 1201 / 1225) loss: 1.645297
# (Epoch 5 / 5) train acc: 0.549000; val_acc: 0.482000
# hidden=200, lr=0.0005, reg=0.0001, scale=0.0001 -> val_acc=0.4820
# (Iteration 1 / 1225) loss: 2.302589
# (Epoch 0 / 5) train acc: 0.148000; val_acc: 0.135000
# (Iteration 101 / 1225) loss: 1.819687
# (Iteration 201 / 1225) loss: 1.678001
# (Epoch 1 / 5) train acc: 0.401000; val_acc: 0.408000
# (Iteration 301 / 1225) loss: 1.671241
# (Iteration 401 / 1225) loss: 1.601711
# (Epoch 2 / 5) train acc: 0.466000; val_acc: 0.455000
# (Iteration 501 / 1225) loss: 1.546535
# (Iteration 601 / 1225) loss: 1.605160
# (Iteration 701 / 1225) loss: 1.473278
# (Epoch 3 / 5) train acc: 0.498000; val_acc: 0.468000
# (Iteration 801 / 1225) loss: 1.466101
# (Iteration 901 / 1225) loss: 1.622541
# (Epoch 4 / 5) train acc: 0.495000; val_acc: 0.465000
# (Iteration 1001 / 1225) loss: 1.449088
# (Iteration 1101 / 1225) loss: 1.309354
# (Iteration 1201 / 1225) loss: 1.463992
# (Epoch 5 / 5) train acc: 0.536000; val_acc: 0.452000
# hidden=200, lr=0.0005, reg=0.0001, scale=5e-05 -> val_acc=0.4520
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.077000; val_acc: 0.087000
# (Iteration 101 / 1225) loss: 1.908750
# (Iteration 201 / 1225) loss: 1.694744
# (Epoch 1 / 5) train acc: 0.421000; val_acc: 0.461000
# (Iteration 301 / 1225) loss: 1.603273
# (Iteration 401 / 1225) loss: 1.578368
# (Epoch 2 / 5) train acc: 0.449000; val_acc: 0.407000
# (Iteration 501 / 1225) loss: 1.559494
# (Iteration 601 / 1225) loss: 1.663857
# (Iteration 701 / 1225) loss: 1.699682
# (Epoch 3 / 5) train acc: 0.492000; val_acc: 0.485000
# (Iteration 801 / 1225) loss: 1.478319
# (Iteration 901 / 1225) loss: 1.304453
# (Epoch 4 / 5) train acc: 0.538000; val_acc: 0.458000
# (Iteration 1001 / 1225) loss: 1.482040
# (Iteration 1101 / 1225) loss: 1.404284
# (Iteration 1201 / 1225) loss: 1.270413
# (Epoch 5 / 5) train acc: 0.525000; val_acc: 0.491000
# hidden=200, lr=0.0005, reg=0.0001, scale=1e-05 -> val_acc=0.4910
# (Iteration 1 / 1225) loss: 2.302634
# (Epoch 0 / 5) train acc: 0.076000; val_acc: 0.070000
# (Iteration 101 / 1225) loss: 2.003984
# (Iteration 201 / 1225) loss: 1.804940
# (Epoch 1 / 5) train acc: 0.375000; val_acc: 0.396000
# (Iteration 301 / 1225) loss: 1.641097
# (Iteration 401 / 1225) loss: 1.551148
# (Epoch 2 / 5) train acc: 0.454000; val_acc: 0.470000
# (Iteration 501 / 1225) loss: 1.773772
# (Iteration 601 / 1225) loss: 1.436004
# (Iteration 701 / 1225) loss: 1.388794
# (Epoch 3 / 5) train acc: 0.476000; val_acc: 0.476000
# (Iteration 801 / 1225) loss: 1.475369
# (Iteration 901 / 1225) loss: 1.294241
# (Epoch 4 / 5) train acc: 0.509000; val_acc: 0.517000
# (Iteration 1001 / 1225) loss: 1.380772
# (Iteration 1101 / 1225) loss: 1.391943
# (Iteration 1201 / 1225) loss: 1.348843
# (Epoch 5 / 5) train acc: 0.575000; val_acc: 0.497000
# hidden=200, lr=0.0001, reg=0.0, scale=0.0001 -> val_acc=0.4970
# (Iteration 1 / 1225) loss: 2.302583
# (Epoch 0 / 5) train acc: 0.074000; val_acc: 0.098000
# (Iteration 101 / 1225) loss: 2.107114
# (Iteration 201 / 1225) loss: 1.832037
# (Epoch 1 / 5) train acc: 0.396000; val_acc: 0.390000
# (Iteration 301 / 1225) loss: 1.855632
# (Iteration 401 / 1225) loss: 1.556745
# (Epoch 2 / 5) train acc: 0.448000; val_acc: 0.433000
# (Iteration 501 / 1225) loss: 1.557659
# (Iteration 601 / 1225) loss: 1.531956
# (Iteration 701 / 1225) loss: 1.453285
# (Epoch 3 / 5) train acc: 0.492000; val_acc: 0.462000
# (Iteration 801 / 1225) loss: 1.323398
# (Iteration 901 / 1225) loss: 1.417685
# (Epoch 4 / 5) train acc: 0.496000; val_acc: 0.494000
# (Iteration 1001 / 1225) loss: 1.398772
# (Iteration 1101 / 1225) loss: 1.488203
# (Iteration 1201 / 1225) loss: 1.374318
# (Epoch 5 / 5) train acc: 0.528000; val_acc: 0.503000
# hidden=200, lr=0.0001, reg=0.0, scale=5e-05 -> val_acc=0.5030
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.115000; val_acc: 0.129000
# (Iteration 101 / 1225) loss: 2.123476
# (Iteration 201 / 1225) loss: 1.899996
# (Epoch 1 / 5) train acc: 0.373000; val_acc: 0.358000
# (Iteration 301 / 1225) loss: 1.704657
# (Iteration 401 / 1225) loss: 1.653000
# (Epoch 2 / 5) train acc: 0.429000; val_acc: 0.444000
# (Iteration 501 / 1225) loss: 1.473840
# (Iteration 601 / 1225) loss: 1.522649
# (Iteration 701 / 1225) loss: 1.605571
# (Epoch 3 / 5) train acc: 0.477000; val_acc: 0.465000
# (Iteration 801 / 1225) loss: 1.566255
# (Iteration 901 / 1225) loss: 1.455702
# (Epoch 4 / 5) train acc: 0.513000; val_acc: 0.492000
# (Iteration 1001 / 1225) loss: 1.410512
# (Iteration 1101 / 1225) loss: 1.393024
# (Iteration 1201 / 1225) loss: 1.372923
# (Epoch 5 / 5) train acc: 0.548000; val_acc: 0.500000
# hidden=200, lr=0.0001, reg=0.0, scale=1e-05 -> val_acc=0.5000
# (Iteration 1 / 1225) loss: 2.302606
# (Epoch 0 / 5) train acc: 0.098000; val_acc: 0.085000
# (Iteration 101 / 1225) loss: 2.016756
# (Iteration 201 / 1225) loss: 1.774004
# (Epoch 1 / 5) train acc: 0.389000; val_acc: 0.395000
# (Iteration 301 / 1225) loss: 1.631951
# (Iteration 401 / 1225) loss: 1.594951
# (Epoch 2 / 5) train acc: 0.451000; val_acc: 0.446000
# (Iteration 501 / 1225) loss: 1.488596
# (Iteration 601 / 1225) loss: 1.482624
# (Iteration 701 / 1225) loss: 1.405675
# (Epoch 3 / 5) train acc: 0.478000; val_acc: 0.464000
# (Iteration 801 / 1225) loss: 1.384547
# (Iteration 901 / 1225) loss: 1.436452
# (Epoch 4 / 5) train acc: 0.513000; val_acc: 0.504000
# (Iteration 1001 / 1225) loss: 1.383531
# (Iteration 1101 / 1225) loss: 1.206044
# (Iteration 1201 / 1225) loss: 1.450956
# (Epoch 5 / 5) train acc: 0.527000; val_acc: 0.511000
# hidden=200, lr=0.0001, reg=0.0001, scale=0.0001 -> val_acc=0.5110
# (Iteration 1 / 1225) loss: 2.302589
# (Epoch 0 / 5) train acc: 0.092000; val_acc: 0.102000
# (Iteration 101 / 1225) loss: 2.035081
# (Iteration 201 / 1225) loss: 1.868587
# (Epoch 1 / 5) train acc: 0.388000; val_acc: 0.366000
# (Iteration 301 / 1225) loss: 1.702890
# (Iteration 401 / 1225) loss: 1.669052
# (Epoch 2 / 5) train acc: 0.479000; val_acc: 0.438000
# (Iteration 501 / 1225) loss: 1.680508
# (Iteration 601 / 1225) loss: 1.434329
# (Iteration 701 / 1225) loss: 1.557378
# (Epoch 3 / 5) train acc: 0.523000; val_acc: 0.472000
# (Iteration 801 / 1225) loss: 1.695885
# (Iteration 901 / 1225) loss: 1.536997
# (Epoch 4 / 5) train acc: 0.491000; val_acc: 0.496000
# (Iteration 1001 / 1225) loss: 1.387244
# (Iteration 1101 / 1225) loss: 1.384370
# (Iteration 1201 / 1225) loss: 1.422597
# (Epoch 5 / 5) train acc: 0.532000; val_acc: 0.509000
# hidden=200, lr=0.0001, reg=0.0001, scale=5e-05 -> val_acc=0.5090
# (Iteration 1 / 1225) loss: 2.302585
# (Epoch 0 / 5) train acc: 0.098000; val_acc: 0.092000
# (Iteration 101 / 1225) loss: 2.102336
# (Iteration 201 / 1225) loss: 1.949645
# (Epoch 1 / 5) train acc: 0.342000; val_acc: 0.369000
# (Iteration 301 / 1225) loss: 1.792776
# (Iteration 401 / 1225) loss: 1.556527
# (Epoch 2 / 5) train acc: 0.446000; val_acc: 0.445000
# (Iteration 501 / 1225) loss: 1.639465
# (Iteration 601 / 1225) loss: 1.540953
# (Iteration 701 / 1225) loss: 1.350067
# (Epoch 3 / 5) train acc: 0.495000; val_acc: 0.453000
# (Iteration 801 / 1225) loss: 1.380267
# (Iteration 901 / 1225) loss: 1.304344
# (Epoch 4 / 5) train acc: 0.523000; val_acc: 0.485000
# (Iteration 1001 / 1225) loss: 1.393482
# (Iteration 1101 / 1225) loss: 1.392640
# (Iteration 1201 / 1225) loss: 1.385574
# (Epoch 5 / 5) train acc: 0.519000; val_acc: 0.489000
# hidden=200, lr=0.0001, reg=0.0001, scale=1e-05 -> val_acc=0.4890
# Best validation accuracy: 0.5110

# %% [markdown]
# # Проверка лучшей модели
#
# Запустите лучшую найденную модель на валидационной и тестовой выборках. Нужно получить более `48%` точности и на валидации, и на тесте.

# %%
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Точность на validation: ', (y_val_pred == data['y_val']).mean())
# Out:
# Точность на validation:  0.511

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
print('Точность на test: ', (y_test_pred == data['y_test']).mean())
# Out:
# Точность на test:  0.514

# %%
# Сохраняем лучшую модель
best_model.save("best_two_layer_net.npy")
# Out:
# best_two_layer_net.npy saved.

# %% [markdown]
# ## Теоретический вопрос 2
#
# После обучения нейросетевого классификатора может оказаться, что точность на тесте заметно ниже, чем на обучении. Как можно уменьшить этот разрыв? Выберите все подходящие варианты.
#
# 1. Обучать на более крупном датасете.
# 2. Добавить больше скрытых нейронов.
# 3. Увеличить силу регуляризации.
# 4. Ничего из перечисленного.
#
# ### Ваш ответ
# > 1, 3
